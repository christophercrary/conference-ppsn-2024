# %%
import sys
import subprocess
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
import json
import builtins

from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
from multiprocessing import Pool

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.size'] = 14
plt.rcParams['text.usetex'] = True

# %% [markdown]
# ### Count tree length with Sympy (not needed with new data)

# %%
# load sympy
from sympy import parse_expr

def count_nodes(expr):
        '''
        Counts the nodes of a sympy expression.

        Parameters
        ----------
        expr : sympy
                 sympy expression as created by SymExpr class.
        '''
        return sum(count_nodes(arg) for arg in expr.args) + 1
        # count = 0
        # for arg in expr.args:
        #     count += self.count_nodes(arg)
        # return count + 1


def sympy_expression_length(expr_string):
    expr = parse_expr(expr_string)
    return count_nodes(expr)

# %%
def read_results(path):
    frames = []

    for d in Path(path).iterdir():
        for f in d.iterdir():
            try:
                # df = pd.read_csv(f)
                df = pd.read_csv(f)
                df['backend'] = str(d).split('/')[-1]
                frames.append(df)
            except Exception as e:
                print(e)
                pass

    return pd.concat(frames)

# %% [markdown]
# ### There results are generated with a Python script which wraps the Operon CLI programs and parses their output into Pandas data frames

# %%
df1 = read_results('./data/full_stat_runs/without_nls/') # results without NLS
df2 = read_results('./data/full_stat_runs/with_nls/')    # results with NLS

df = pd.concat([df1, df2])
df.shape
# Out:
# (10320892, 20)

# %%
df
# Out:
#                    problem                        symbols  generation  \
# 0       Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh         0.0
# 1       Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh         1.0
# 2       Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh         2.0
# 3       Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh         3.0
# 4       Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh         4.0
# ...                    ...                            ...         ...
# 218171     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       138.0
# 218172     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       139.0
# 218173     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       140.0
# 218174     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       141.0
# 218175     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       142.0
#
#         r2_train  r2_test  mae_train  mae_test  nmse_train  nmse_test  \
# 0          0.387    0.085     4.0700     5.550    0.613000      0.915
# 1          0.436    0.251     4.0800     5.100    0.564000      0.749
# 2          0.514    0.337     3.7000     4.720    0.486000      0.663
# 3          0.580    0.159     3.4400     4.780    0.420000      0.841
# 4          0.595    0.354     3.4200     4.650    0.405000      0.646
# ...          ...      ...        ...       ...         ...        ...
# 218171     1.000    0.838     0.0145     0.402    0.000336      0.162
# 218172     1.000    0.838     0.0145     0.402    0.000336      0.162
# 218173     1.000    0.838     0.0145     0.402    0.000336      0.162
# 218174     1.000    0.838     0.0145     0.402    0.000336      0.162
# 218175     1.000    0.838     0.0145     0.402    0.000336      0.162
#
#              avg_fit  avg_len      eval  res_eval  jac_eval   opt_time  \
# 0       2.580000e+38     42.3    2000.0    1000.0       0.0        0.0
# 1       5.950000e+37     24.2    4000.0    2000.0       0.0        0.0
# 2      -9.220000e-02     19.0    6000.0    3000.0       0.0        0.0
# 3      -1.670000e-01     20.3    8000.0    4000.0       0.0        0.0
# 4      -2.490000e-01     20.5   10000.0    5000.0       0.0        0.0
# ...              ...      ...       ...       ...       ...        ...
# 218171 -9.160000e-01     39.6  278000.0  659970.0  317553.0  7187022.0
# 218172 -9.150000e-01     39.6  280000.0  664742.0  319823.0  7248563.0
# 218173 -9.140000e-01     39.2  282000.0  669515.0  322140.0  7310763.0
# 218174 -9.150000e-01     39.3  284000.0  674296.0  324460.0  7371261.0
# 218175 -9.150000e-01     39.3  284426.0  675293.0  324922.0  7384731.0
#
#                 seed   elapsed  energy  \
# 0       3.157811e+09  0.001781     NaN
# 1       3.157811e+09  0.003214     NaN
# 2       3.157811e+09  0.004559     NaN
# 3       3.157811e+09  0.005901     NaN
# 4       3.157811e+09  0.007218     NaN
# ...              ...       ...     ...
# 218171  1.630222e+09  0.412368     NaN
# 218172  1.630222e+09  0.415653     NaN
# 218173  1.630222e+09  0.418974     NaN
# 218174  1.630222e+09  0.422244     NaN
# 218175  1.630222e+09  0.423760   65.61
#
#                                                expression  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 218171                                                NaN
# 218172                                                NaN
# 218173                                                NaN
# 218174                                                NaN
# 218175  (0.002075307071208953857422 + (0.9990833997726...
#
#                           backend
# 0       Mad_Transcendental_Faster
# 1       Mad_Transcendental_Faster
# 2       Mad_Transcendental_Faster
# 3       Mad_Transcendental_Faster
# 4       Mad_Transcendental_Faster
# ...                           ...
# 218171                        Stl
# 218172                        Stl
# 218173                        Stl
# 218174                        Stl
# 218175                        Stl
#
# [10320892 rows x 20 columns]

# %%
len(df.expression.unique())
# Out:
# 17908

# %% [markdown]
# ### Check the actual $R^2$ (not within the fast framework but with Eigen/Stl)
#
# Here, we call the `operon_parse_model` CLI tool, which will parse the model expressions and re-evaluate the output using the STL backend. The predictions are rescaled again using linear scaling.
# This is a lengthy operation (the original data frame was 18000 rows), therefore we will parallelize it.

# %% [markdown]
# #### First, load problem data
#
# This will need to be passed as arguments to `operon_parse_model`.

# %%
# we need to know some things about the data
data_path = './data/problems'

all_files  = list(os.listdir(data_path)) if os.path.isdir(data_path) else [ os.path.basename(data_path) ]
data_files = sorted([ f for f in all_files if f.endswith('.json') ])

problem_info = {}

# aggregate problem information that we can use to evaluate expressions
for f in data_files:
    with builtins.open(os.path.join(data_path, f), 'r') as h:
        info           = json.load(h)
        metadata       = info['metadata']
        target         = metadata['target']
        training_rows  = metadata['training_rows']
        training_start = training_rows['start']
        training_end   = training_rows['end']
        test_rows      = metadata['test_rows']
        test_start     = test_rows['start']
        test_end       = test_rows['end']
        problem_name   = metadata['name']
        problem_csv    = metadata['filename']

    problem_data = pd.read_csv(os.path.join(data_path, problem_csv))
    problem_info[problem_name] = {
        'name' : problem_name,
        'training_range' : (training_start, training_end),
        'test_range' : (test_start, test_end),
        'target' : target,
        'data' : problem_data
    }

problem_info
# Out:
# {'Airfoil Self-Noise': {'name': 'Airfoil Self-Noise',
#   'training_range': (0, 1000),
#   'test_range': (1000, 1503),
#   'target': 'Y',
#   'data':         X1    X2      X3    X4        X5        Y
#   0      800   0.0  0.3048  71.3  0.002663  126.201
#   1     1000   0.0  0.3048  71.3  0.002663  125.201
#   2     1250   0.0  0.3048  71.3  0.002663  125.951
#   3     1600   0.0  0.3048  71.3  0.002663  127.591
#   4     2000   0.0  0.3048  71.3  0.002663  127.461
#   ...    ...   ...     ...   ...       ...      ...
#   1498  2500  15.6  0.1016  39.6  0.052849  110.264
#   1499  3150  15.6  0.1016  39.6  0.052849  109.254
#   1500  4000  15.6  0.1016  39.6  0.052849  106.604
#   1501  5000  15.6  0.1016  39.6  0.052849  106.224
#   1502  6300  15.6  0.1016  39.6  0.052849  104.204
#
#   [1503 rows x 6 columns]},
#  'Chemical-I': {'name': 'Chemical-I',
#   'training_range': (0, 711),
#   'test_range': (711, 1066),
#   'target': 'y',
#   'data':            x1       x2       x3       x4       x5       x6        x7  \
#   0     52.0085  58497.7  26.9956 -17.3726   0.0000  38.0390   833.730
#   1     52.9874  59181.1  27.0061 -17.3698   0.0000  38.0437   863.584
#   2     54.0505  58879.2  26.8679 -17.3766   0.0000  38.0579   886.660
#   3     55.3182  58982.0  27.1852 -17.3743   0.0000  38.0321   886.676
#   4     46.5388  59270.3  26.4420 -17.1840   0.0000  35.9390   761.306
#   ...       ...      ...      ...      ...      ...      ...       ...
#   1061  65.0246  52689.9  25.4799 -17.1756  54.9912  36.9564   992.241
#   1062  65.0224  52387.0  25.6576 -17.1777  54.8819  37.0002   997.332
#   1063  65.0246  52529.3  25.7275 -17.1732  55.0610  37.0483   995.142
#   1064  65.8768  53154.2  26.2064 -17.1791  54.9547  36.9910  1002.070
#   1065  67.0212  53489.1  26.7524 -17.1778  55.3093  36.9803  1006.920
#
#               x8       x9      x10  ...      x49      x50      x51      x52  \
#   0     0.000000  27.0007  458.622  ...  357.161  361.154  193.519  260.310
#   1     0.013005  27.0040  462.554  ...  356.725  360.500  194.846  265.333
#   2     0.000000  26.9982  464.362  ...  355.688  359.868  195.577  267.643
#   3     0.000000  27.0047  467.475  ...  356.751  360.178  193.496  261.277
#   4     0.000000  26.9944  435.559  ...  354.504  357.327  319.038  357.359
#   ...        ...      ...      ...  ...      ...      ...      ...      ...
#   1061  0.000000  26.2459  513.654  ...  349.010  341.825  310.599  350.581
#   1062  0.000000  26.2522  514.455  ...  348.910  340.155  309.089  349.541
#   1063  0.000000  26.2402  516.200  ...  348.137  339.317  307.759  348.629
#   1064  0.000000  26.4054  522.160  ...  348.651  341.896  306.558  348.504
#   1065  0.001450  26.5630  536.044  ...  349.438  342.763  307.099  349.300
#
#             x53      x54      x55       x56      x57      y
#   0     255.534  24.1038  24.0391  12.90050  66.2633  4.027
#   1     268.477  23.8604  23.7483  12.72390  66.8367  4.154
#   2     272.800  23.6713  23.5869  12.58770  67.6773  4.047
#   3     263.260  23.8581  23.7869  12.62290  67.7128  4.118
#   4     359.979  24.7091  24.2601  12.58920  65.7425  4.743
#   ...       ...      ...      ...       ...      ...    ...
#   1061  354.438  22.1793  22.3652   8.06546  76.3706  2.680
#   1062  353.975  22.2315  21.9315   8.55232  76.6307  2.800
#   1063  353.262  22.2243  21.7814   8.44026  77.7569  2.840
#   1064  353.355  22.2462  22.0601   7.38168  79.3015  2.880
#   1065  354.146  22.2034  22.0357   6.04010  80.6965  2.870
#
#   [1066 rows x 58 columns]},
#  'Concrete Compressive Strength': {'name': 'Concrete Compressive Strength',
#   'training_range': (0, 500),
#   'test_range': (500, 1000),
#   'target': 'Y',
#   'data':          X1     X2     X3     X4    X5      X6     X7   X8      Y
#   0     540.0    0.0    0.0  162.0   2.5  1040.0  676.0   28  79.99
#   1     540.0    0.0    0.0  162.0   2.5  1055.0  676.0   28  61.89
#   2     332.5  142.5    0.0  228.0   0.0   932.0  594.0  270  40.27
#   3     332.5  142.5    0.0  228.0   0.0   932.0  594.0  365  41.05
#   4     198.6  132.4    0.0  192.0   0.0   978.4  825.5  360  44.30
#   ...     ...    ...    ...    ...   ...     ...    ...  ...    ...
#   1025  276.4  116.0   90.3  179.6   8.9   870.1  768.3   28  44.28
#   1026  322.2    0.0  115.6  196.0  10.4   817.9  813.4   28  31.18
#   1027  148.5  139.4  108.6  192.7   6.1   892.4  780.0   28  23.70
#   1028  159.1  186.7    0.0  175.6  11.3   989.6  788.9   28  32.77
#   1029  260.9  100.5   78.3  200.6   8.6   864.5  761.5   28  32.40
#
#   [1030 rows x 9 columns]},
#  'Friedman-I': {'name': 'Friedman-I',
#   'training_range': (0, 5000),
#   'test_range': (5000, 10000),
#   'target': 'Y',
#   'data':             X1        X2        X3        X4        X5        X6        X7  \
#   0     0.236620  0.600081  0.487645  0.296938  0.020660  0.947861  0.166180
#   1     0.696607  0.091203  0.945583  0.760802  0.545135  0.485854  0.641803
#   2     0.605851  0.242506  0.856880  0.920138  0.635745  0.332722  0.550796
#   3     0.867608  0.480810  0.618636  0.681835  0.905314  0.063228  0.781287
#   4     0.481173  0.085859  0.312654  0.758124  0.698511  0.852007  0.706698
#   ...        ...       ...       ...       ...       ...       ...       ...
#   9995  0.152291  0.608075  0.798017  0.437151  0.088499  0.457848  0.785671
#   9996  0.555293  0.404170  0.378284  0.343330  0.945436  0.599509  0.140751
#   9997  0.879570  0.350540  0.564407  0.833892  0.796003  0.901045  0.475195
#   9998  0.371573  0.556333  0.481098  0.885761  0.959099  0.843251  0.459232
#   9999  0.616027  0.262599  0.880784  0.765963  0.859846  0.056052  0.696978
#
#               X8        X9       X10         Y
#   0     0.844180  0.095139  0.107777  5.229978
#   1     0.339291  0.588332  0.583263  8.014625
#   2     0.498384  0.749286  0.734824  6.343234
#   3     0.228830  0.979792  0.973143  8.076996
#   4     0.015402  0.227186  0.344127  2.704218
#   ...        ...       ...       ...       ...
#   9995  0.101785  0.529337  0.409187  8.280172
#   9996  0.514037  0.932858  0.734728  2.099220
#   9997  0.493853  0.256542  0.554104  6.179670
#   9998  0.923468  0.230194  0.925057  7.902666
#   9999  0.509691  0.659035  0.529565  6.713303
#
#   [10000 rows x 11 columns]},
#  'Friedman-II': {'name': 'Friedman-II',
#   'training_range': (0, 5000),
#   'test_range': (5000, 10000),
#   'target': 'Y',
#   'data':             X1        X2        X3        X4        X5        X6        X7  \
#   0     0.726928  0.818380  0.021370  0.430856  0.150760  0.134666  0.763400
#   1     0.206299  0.372173  0.545890  0.877127  0.657711  0.674783  0.303373
#   2     0.115690  0.461112  0.636516  0.788188  0.504182  0.523243  0.394104
#   3     0.346181  0.199370  0.906008  0.549869  0.765878  0.753691  0.132424
#   4     0.366877  0.908266  0.150100  0.524423  0.139540  0.163506  0.577054
#   ...        ...       ...       ...       ...       ...       ...       ...
#   9995  0.422191  0.715242  0.737555  0.121192  0.918851  0.504504  0.730911
#   9996  0.495247  0.745874  0.751866  0.962310  0.571786  0.319917  0.087162
#   9997  0.314155  0.331204  0.574751  0.396880  0.678504  0.891578  0.904498
#   9998  0.653409  0.709158  0.757741  0.399629  0.066750  0.231339  0.515987
#   9999  0.430527  0.820640  0.994083  0.289630  0.205189  0.514756  0.846008
#
#               X8        X9       X10          Y
#   0     0.613516  0.806340  0.345648  19.541618
#   1     0.077278  0.252619  0.838801  15.650385
#   2     0.228598  0.413673  0.999854  11.497776
#   3     0.498166  0.175368  0.730301  16.344805
#   4     0.598147  0.500379  0.003487  18.508820
#   ...        ...       ...       ...        ...
#   9995  0.050087  0.806061  0.247622  14.385493
#   9996  0.241806  0.398212  0.266331  21.571907
#   9997  0.523086  0.238822  0.410296  10.373555
#   9998  0.534809  0.125276  0.494732  16.378532
#   9999  0.091659  0.242226  0.377310  18.067678
#
#   [10000 rows x 11 columns]},
#  'Spatial Coevolution': {'name': 'Spatial Coevolution',
#   'training_range': (0, 676),
#   'test_range': (676, 1676),
#   'target': 'F',
#   'data':              X         Y         F
#   0    -5.000000 -5.000000  1.996805
#   1    -5.000000 -4.600000  1.996174
#   2    -5.000000 -4.200000  1.995199
#   3    -5.000000 -3.800000  1.993630
#   4    -5.000000 -3.400000  1.990975
#   ...        ...       ...       ...
#   1671 -4.938949  1.468229  1.821238
#   1672 -4.677314 -4.219892  1.994771
#   1673 -1.748726 -4.661037  1.901283
#   1674 -2.860700  4.124743  1.981845
#   1675  2.152705  4.899040  1.953774
#
#   [1676 rows x 3 columns]},
#  'Poly-10': {'name': 'Poly-10',
#   'training_range': (0, 250),
#   'test_range': (250, 500),
#   'target': 'Y',
#   'data':            X1        X2        X3        X4        X5        X6        X7  \
#   0   -0.996123 -0.342333 -0.585257 -0.018694 -0.306348  0.838439  0.392142
#   1    0.115019  0.710255  0.467337  0.901264  0.672314 -0.206357 -0.523732
#   2    0.312172  0.903454  0.145401  0.703654  0.994251 -0.399544 -0.830215
#   3    0.773182  0.426966  0.684536  0.242792  0.455114 -0.923057 -0.369353
#   4   -0.795812  0.140288 -0.372888 -0.552319  0.360903 -0.146417 -0.131492
#   ..        ...       ...       ...       ...       ...       ...       ...
#   495  0.980172  0.297834  0.898837  0.840485  0.309604 -0.675749  0.690701
#   496 -0.969678  0.528678  0.234307  0.939680 -0.734328 -0.822236  0.762510
#   497  0.104168  0.138986 -0.241392  0.089536 -0.287464  0.985869  0.269701
#   498 -0.579716 -0.918497 -0.030719 -0.101837 -0.648874  0.019037 -0.997279
#   499 -0.040481 -0.317086  0.807555 -0.615642  0.025667  0.278071  0.246918
#
#              X8        X9       X10         Y
#   0   -0.363563 -0.502026 -0.334063  0.455120
#   1    0.747595  0.386546  0.718585  0.271566
#   2    0.929594  0.189196  0.896221 -0.114001
#   3    0.406201  0.728181  0.435235 -0.406737
#   4   -0.341703 -0.880033 -0.927341 -0.101251
#   ..        ...       ...       ...       ...
#   495  0.437179 -0.160767 -0.746223  1.182580
#   496  0.382103  0.821220 -0.165422 -0.264014
#   497  0.581995 -0.256511 -0.652655 -0.142424
#   498 -0.924197  0.668955  0.324186  0.909802
#   499 -0.830316  0.759489 -0.312980 -0.555065
#
#   [500 rows x 11 columns]},
#  'Vladislavleva-1': {'name': 'Vladislavleva-1',
#   'training_range': (0, 100),
#   'test_range': (100, 2125),
#   'target': 'Y',
#   'data':             X1        X2         Y
#   0     2.856106  0.360282  0.005521
#   1     1.197742  2.307870  0.777461
#   2     0.636991  2.664979  0.714248
#   3     1.489808  3.633426  0.316623
#   4     1.054668  3.063933  0.656787
#   ...        ...       ...       ...
#   2120  4.200000  3.800000  0.000012
#   2121  4.200000  3.900000  0.000011
#   2122  4.200000  4.000000  0.000010
#   2123  4.200000  4.100000  0.000009
#   2124  4.200000  4.200000  0.000009
#
#   [2125 rows x 3 columns]},
#  'Vladislavleva-2': {'name': 'Vladislavleva-2',
#   'training_range': (0, 100),
#   'test_range': (100, 321),
#   'target': 'Y',
#   'data':          X         Y
#   0     0.05 -0.000006
#   1     0.15 -0.000420
#   2     0.25 -0.002744
#   3     0.35 -0.008657
#   4     0.45 -0.018880
#   ..     ...       ...
#   316  10.30 -0.024908
#   317  10.35 -0.023590
#   318  10.40 -0.022009
#   319  10.45 -0.020210
#   320  10.50 -0.018242
#
#   [321 rows x 2 columns]},
#  'Vladislavleva-3': {'name': 'Vladislavleva-3',
#   'training_range': (0, 600),
#   'test_range': (600, 5683),
#   'target': 'Y',
#   'data':          X1     X2         Y
#   0      0.05   0.05  0.000029
#   1      0.05   2.05  0.000017
#   2      0.05   4.05  0.000006
#   3      0.05   6.05 -0.000006
#   4      0.05   8.05 -0.000018
#   ...     ...    ...       ...
#   5678  10.50   8.50 -0.063848
#   5679  10.50   9.00 -0.072969
#   5680  10.50   9.50 -0.082090
#   5681  10.50  10.00 -0.091211
#   5682  10.50  10.50 -0.100333
#
#   [5683 rows x 3 columns]},
#  'Vladislavleva-4': {'name': 'Vladislavleva-4',
#   'training_range': (0, 1024),
#   'test_range': (1024, 6024),
#   'target': 'Y',
#   'data':             X1        X2        X3        X4        X5         Y
#   0     0.449094  2.076738  3.050015  0.900147  3.061193  0.596119
#   1     3.794218  5.129949  0.396415  4.046290  0.395491  0.402831
#   2     4.328545  5.720715  0.976707  3.139348  0.986077  0.447701
#   3     5.758453  4.290885  2.359380  4.709435  2.369122  0.555370
#   4     5.206145  1.013707  5.376638  4.841939  1.194497  0.382945
#   ...        ...       ...       ...       ...       ...       ...
#   6019  1.340250  4.197643  4.094925  4.761271  2.149590  0.703569
#   6020  3.600169  5.850356  5.880432  3.190636  3.469881  0.453746
#   6021  2.005422  1.184675  1.047613  0.719154  3.198255  0.545317
#   6022  1.407026  0.270056  4.005648  4.825442  3.154057  0.516597
#   6023 -0.037715  4.027571  1.073416 -0.113445  1.407380  0.320253
#
#   [6024 rows x 6 columns]},
#  'Vladislavleva-5': {'name': 'Vladislavleva-5',
#   'training_range': (0, 300),
#   'test_range': (300, 3000),
#   'target': 'Y',
#   'data':             X1        X2        X3         Y
#   0     0.533651  1.909485  0.488798 -0.207210
#   1     1.403757  1.398741  1.446707 -0.321722
#   2     1.215090  1.310031  1.254022 -0.108721
#   3     1.740719  1.040477  1.718748 -1.786259
#   4     0.227768  1.261025  0.505511 -0.737199
#   ...        ...       ...       ...       ...
#   2995  2.050000  2.050000  1.450000 -0.424276
#   2996  2.050000  2.050000  1.600000 -0.565701
#   2997  2.050000  2.050000  1.750000 -0.707126
#   2998  2.050000  2.050000  1.900000 -0.848552
#   2999  2.050000  2.050000  2.050000 -0.989977
#
#   [3000 rows x 4 columns]},
#  'Vladislavleva-6': {'name': 'Vladislavleva-6',
#   'training_range': (0, 30),
#   'test_range': (30, 93666),
#   'target': 'Y',
#   'data':              X1        X2         Y
#   0      1.015842  1.619899 -0.250299
#   1      3.876124  4.763136 -0.203988
#   2      3.360229  5.279783 -0.699414
#   3      4.696810  3.761587  4.882697
#   4      3.041094  1.823653 -0.150597
#   ...         ...       ...       ...
#   93661  6.050000  5.970000 -1.319025
#   93662  6.050000  5.990000 -1.327304
#   93663  6.050000  6.010000 -1.335052
#   93664  6.050000  6.030000 -1.342265
#   93665  6.050000  6.050000 -1.348942
#
#   [93666 rows x 3 columns]},
#  'Vladislavleva-7': {'name': 'Vladislavleva-7',
#   'training_range': (0, 300),
#   'test_range': (300, 1300),
#   'target': 'Y',
#   'data':             X1        X2         Y
#   0     1.976493  5.337109 -3.236579
#   1     5.228736  2.659133 -2.753810
#   2     5.809066  1.693500 -1.954399
#   3     4.192102  0.123048 -4.785222
#   4     2.703527  1.746222  0.807447
#   ...        ...       ...       ...
#   1295  0.450467  1.179568  3.534454
#   1296  0.297521  3.592938  0.393546
#   1297  3.884689  0.930077 -1.137941
#   1298  1.229190  1.554492  3.506003
#   1299  2.879191  5.815408 -2.128729
#
#   [1300 rows x 3 columns]},
#  'Vladislavleva-8': {'name': 'Vladislavleva-8',
#   'training_range': (0, 50),
#   'test_range': (50, 1206),
#   'target': 'Y',
#   'data':             X1        X2         Y
#   0     4.423332  6.016067  0.105591
#   1     1.277503  2.681842  0.889672
#   2     0.731361  2.136616  2.670763
#   3     2.114037  0.706792 -0.715034
#   4     0.832712  3.259916  1.742897
#   ...        ...       ...       ...
#   1201  6.350000  5.550000  0.829128
#   1202  6.350000  5.750000  0.693086
#   1203  6.350000  5.950000  0.586601
#   1204  6.350000  6.150000  0.502424
#   1205  6.350000  6.350000  0.435226
#
#   [1206 rows x 3 columns]}}

# %%
from sklearn.metrics import r2_score
import hashlib
from scipy.stats import zscore

def problem_actual_name(problem_name):
    names = {
        'Airfoil Self-Noise' : 'AirfoilSelfNoise',
        'Concrete Compressive Strength' : 'Concrete',
        'Spatial Coevolution' : 'Pagie-1'
    }
    return names[problem_name] if problem_name in names else problem_name


def parse_float(s):
    try:
        f = float(s)
    except:
        f = np.nan
    return f


def evaluate_with_backend(backend, pname, expr, rg):
    a, b = rg
    cmd = [f'./bin/build_{backend}/cli/operon_parse_model', '--dataset', f'./data/problems/{pname}.csv', '--range', f'{a}:{b}', '--format', ':.20f', f"'{expr}'"]
    out = subprocess.check_output(cmd, shell=False)
    val = np.array([parse_float(x) for x in (v.decode('ascii') for v in out.split(b'\n')) if x != ''])
    return val


# useful in case we want to remember an expression by its hash to look at it later
def hash_expr(expr):
    try:
        h = hashlib.md5(expr.encode("utf-8")).hexdigest()[:7]
    except:
        h = 0

# %%
df.shape
# Out:
# (10320892, 20)

# %%
processed_rows = [None] * df.shape[0]

# %%
def fit_lstsq(y_pred, y_true):
    A = np.vstack([y_pred, np.ones(len(y_pred))]).T
    return np.linalg.lstsq(A, y_true, rcond=None)[0]


def evaluate_expr(problem, backend, expr):
    pass


def process_dataframe(df):
    for i, row in df.dropna(subset=['expression'], axis=0).iterrows():
        symbols = row['symbols']
        backend = row['backend']
        problem = row['problem']
        expr    = row['expression']
        expr_hash = hash_expr(expr)
        energy  = row['energy']

        # if np.isnan(energy):
        #     df.loc[i, 'r2_train_v'] = np.nan
        #     df.loc[i, 'r2_test_v'] = np.nan

        #     df.loc[i, 'r2_train_b'] = np.nan
        #     df.loc[i, 'r2_test_b'] = np.nan
        #     continue

        pname   = problem_actual_name(problem)
        pinfo   = problem_info[problem]
        data    = pinfo['data']

        training_start, training_end = pinfo['training_range']
        test_start, test_end = pinfo['test_range']

        # get the true target values from the dataset
        y_true_train = data.iloc[training_start:training_end,-1]
        y_true_test  = data.iloc[test_start:test_end,-1]

        y_stl_train = evaluate_with_backend('Stl', pname, expr, (training_start, training_end))
        y_stl_test  = evaluate_with_backend('Stl', pname, expr, (test_start, test_end))

        y_bak_train = evaluate_with_backend(backend, pname, expr, (training_start, training_end))
        y_bak_test  = evaluate_with_backend(backend, pname, expr, (test_start, test_end))

        np.nan_to_num(y_stl_train, copy=False)
        np.nan_to_num(y_stl_test,  copy=False)
        np.nan_to_num(y_bak_train, copy=False)
        np.nan_to_num(y_bak_test,  copy=False)

        # compute STL R2 values
        try:
            m, c = fit_lstsq(y_stl_train, y_true_train)
        except:
            m, c = 1, 0

        y_stl_train = y_stl_train * m + c
        y_stl_test = y_stl_test * m + c # reuse m, c from train

        try:
            r2_train_stl = r2_score(y_true_train, y_stl_train)
        except:
            r2_train_stl = 0

        try:
            r2_test_stl  = r2_score(y_true_test, y_stl_test)
        except:
            r2_test_stl  = 0

        # compute backend R2 values
        try:
            m, c = fit_lstsq(y_bak_train, y_true_train)
        except:
            m, c = 1, 0

        y_bak_train = y_bak_train * m + c
        y_bak_test = y_bak_test * m + c # reuse m, c from train

        try:
            r2_train_bak = r2_score(y_true_train, y_bak_train)
        except:
            r2_train_bak = 0

        try:
            r2_test_bak = r2_score(y_true_test, y_bak_test)
        except:
            r2_test_bak = 0

        df.loc[i, 'r2_train_v'] = r2_train_stl
        df.loc[i, 'r2_test_v'] = r2_test_stl

        df.loc[i, 'r2_train_b'] = r2_train_bak
        df.loc[i, 'r2_test_b'] = r2_test_bak

    return df


num_threads = 16
with Pool(num_threads) as p:
    parts = np.array_split(df, num_threads)
    results = p.map(process_dataframe, parts)

# %%
df = pd.concat(results)

# %%
df.to_csv('results_full.csv.gz', index=False, compression='gzip')

# %%
df.shape
# Out:
# (10320892, 24)

# %%
df1 = df[df.jac_eval == 0].dropna(subset=['expression'], axis=0).reset_index()
for k, v in df1.groupby(['problem', 'backend']):
    print(k, v['r2_test_v'].median())
# Out:
# ('Airfoil Self-Noise', 'Eigen') 0.604055138990477
# ('Airfoil Self-Noise', 'Mad_Transcendental_Fast') 0.6300689140836542
# ('Airfoil Self-Noise', 'Mad_Transcendental_Faster') 0.586487242522215
# ('Airfoil Self-Noise', 'Mad_Transcendental_Fastest') 0.599438919471242
# ('Airfoil Self-Noise', 'Stl') 0.6179560104480541
# ('Airfoil Self-Noise', 'Vdt') 0.6470217701354558
# ('Chemical-I', 'Eigen') 0.6978559676775407
# ('Chemical-I', 'Mad_Transcendental_Fast') 0.7009939412575155
# ('Chemical-I', 'Mad_Transcendental_Faster') 0.7122741980622302
# ('Chemical-I', 'Mad_Transcendental_Fastest') 0.7272092144985605
# ('Chemical-I', 'Stl') 0.7083436533914131
# ('Chemical-I', 'Vdt') 0.7195703657637675
# ('Concrete Compressive Strength', 'Eigen') 0.48138655935268654
# ('Concrete Compressive Strength', 'Mad_Transcendental_Fast') 0.4777827880523948
# ('Concrete Compressive Strength', 'Mad_Transcendental_Faster') 0.4900229056540837
# ('Concrete Compressive Strength', 'Mad_Transcendental_Fastest') 0.47019971744395767
# ('Concrete Compressive Strength', 'Stl') 0.4834511911110748
# ('Concrete Compressive Strength', 'Vdt') 0.4887698825640568
# ('Friedman-I', 'Eigen') 0.8612911320165797
# ('Friedman-I', 'Mad_Transcendental_Fast') 0.8611619695474193
# ('Friedman-I', 'Mad_Transcendental_Faster') 0.860289012402834
# ('Friedman-I', 'Mad_Transcendental_Fastest') 0.8465036497512032
# ('Friedman-I', 'Stl') 0.8607364798866598
# ('Friedman-I', 'Vdt') 0.8604123896805144
# ('Friedman-II', 'Eigen') 0.959938341264831
# ('Friedman-II', 'Mad_Transcendental_Fast') 0.9601770405449364
# ('Friedman-II', 'Mad_Transcendental_Faster') 0.9600566803373576
# ('Friedman-II', 'Mad_Transcendental_Fastest') 0.9568723885137611
# ('Friedman-II', 'Stl') 0.960032580448511
# ('Friedman-II', 'Vdt') 0.9600718570293856
# ('Poly-10', 'Eigen') 0.8775888712719976
# ('Poly-10', 'Mad_Transcendental_Fast') 0.8805766947046197
# ('Poly-10', 'Mad_Transcendental_Faster') 0.8778375285628668
# ('Poly-10', 'Mad_Transcendental_Fastest') 0.8750341251540205
# ('Poly-10', 'Stl') 0.889327604713691
# ('Poly-10', 'Vdt') 0.8862085609315951
# ('Spatial Coevolution', 'Eigen') 0.9970125895557009
# ('Spatial Coevolution', 'Mad_Transcendental_Fast') 0.9969762856443047
# ('Spatial Coevolution', 'Mad_Transcendental_Faster') 0.9944514514023672
# ('Spatial Coevolution', 'Mad_Transcendental_Fastest') 0.9909383255091084
# ('Spatial Coevolution', 'Stl') 0.9968627628835204
# ('Spatial Coevolution', 'Vdt') 0.9973613575412483
# ('Vladislavleva-1', 'Eigen') 0.9905744224161952
# ('Vladislavleva-1', 'Mad_Transcendental_Fast') 0.9915282254904481
# ('Vladislavleva-1', 'Mad_Transcendental_Faster') 0.9882471822943721
# ('Vladislavleva-1', 'Mad_Transcendental_Fastest') 0.9872417981615791
# ('Vladislavleva-1', 'Stl') 0.988872236004642
# ('Vladislavleva-1', 'Vdt') 0.9908282726535631
# ('Vladislavleva-2', 'Eigen') 0.9961370929589752
# ('Vladislavleva-2', 'Mad_Transcendental_Fast') 0.9959342000138451
# ('Vladislavleva-2', 'Mad_Transcendental_Faster') 0.9952276544975263
# ('Vladislavleva-2', 'Mad_Transcendental_Fastest') 0.9901646844011863
# ('Vladislavleva-2', 'Stl') 0.9968526587120901
# ('Vladislavleva-2', 'Vdt') 0.9949860168080626
# ('Vladislavleva-3', 'Eigen') 0.9870846813127991
# ('Vladislavleva-3', 'Mad_Transcendental_Fast') 0.9892082869404515
# ('Vladislavleva-3', 'Mad_Transcendental_Faster') 0.9861480587045508
# ('Vladislavleva-3', 'Mad_Transcendental_Fastest') 0.9744508245115135
# ('Vladislavleva-3', 'Stl') 0.9879132167808483
# ('Vladislavleva-3', 'Vdt') 0.9844397043430617
# ('Vladislavleva-4', 'Eigen') 0.9908728740478163
# ('Vladislavleva-4', 'Mad_Transcendental_Fast') 0.990640513897521
# ('Vladislavleva-4', 'Mad_Transcendental_Faster') 0.9909067343095401
# ('Vladislavleva-4', 'Mad_Transcendental_Fastest') 0.9876951059731574
# ('Vladislavleva-4', 'Stl') 0.9906495637378867
# ('Vladislavleva-4', 'Vdt') 0.9907784296571762
# ('Vladislavleva-5', 'Eigen') 0.9996562500486617
# ('Vladislavleva-5', 'Mad_Transcendental_Fast') 0.9990375056114422
# ('Vladislavleva-5', 'Mad_Transcendental_Faster') 0.9994508552351589
# ('Vladislavleva-5', 'Mad_Transcendental_Fastest') 0.9975863523009182
# ('Vladislavleva-5', 'Stl') 0.9993246167991546
# ('Vladislavleva-5', 'Vdt') 0.9991153078262041
# ('Vladislavleva-6', 'Eigen') 0.9999902171864019
# ('Vladislavleva-6', 'Mad_Transcendental_Fast') 0.9997467368018078
# ('Vladislavleva-6', 'Mad_Transcendental_Faster') 0.9999785415600491
# ('Vladislavleva-6', 'Mad_Transcendental_Fastest') 0.9937239028106479
# ('Vladislavleva-6', 'Stl') 0.9999606861958104
# ('Vladislavleva-6', 'Vdt') 0.999960914379739
# ('Vladislavleva-7', 'Eigen') 0.897280724973676
# ('Vladislavleva-7', 'Mad_Transcendental_Fast') 0.8976934584735904
# ('Vladislavleva-7', 'Mad_Transcendental_Faster') 0.8979437208029984
# ('Vladislavleva-7', 'Mad_Transcendental_Fastest') 0.8911196150650798
# ('Vladislavleva-7', 'Stl') 0.9028827908612571
# ('Vladislavleva-7', 'Vdt') 0.9004815732081795
# ('Vladislavleva-8', 'Eigen') 0.7899572044915362
# ('Vladislavleva-8', 'Mad_Transcendental_Fast') 0.7359621005294763
# ('Vladislavleva-8', 'Mad_Transcendental_Faster') 0.805347966371628
# ('Vladislavleva-8', 'Mad_Transcendental_Fastest') 0.7459695906858005
# ('Vladislavleva-8', 'Stl') 0.8172973283417262
# ('Vladislavleva-8', 'Vdt') 0.7378991225362859

# %%
df2 = df[df.jac_eval > 0].dropna(subset=['expression'], axis=0).reset_index(drop=True)
df2.shape
# Out:
# (9000, 24)

# %%
df2.r2_train_v = df2.r2_train_v.fillna(0.0).clip(0, 1)
df2.r2_test_v = df2.r2_test_v.fillna(0.0).clip(0, 1)

for k, v in df2.groupby(['problem', 'backend']):
    print(k, v['r2_test_v'].median())
# Out:
# ('Airfoil Self-Noise', 'Eigen') 0.5811912219303106
# ('Airfoil Self-Noise', 'Mad_Transcendental_Fast') 0.5658330196071115
# ('Airfoil Self-Noise', 'Mad_Transcendental_Faster') 0.5821834533765583
# ('Airfoil Self-Noise', 'Mad_Transcendental_Fastest') 0.5459158453538014
# ('Airfoil Self-Noise', 'Stl') 0.5718915301909114
# ('Airfoil Self-Noise', 'Vdt') 0.5706119177851965
# ('Chemical-I', 'Eigen') 0.811896665675653
# ('Chemical-I', 'Mad_Transcendental_Fast') 0.8147243841338243
# ('Chemical-I', 'Mad_Transcendental_Faster') 0.8151623594925014
# ('Chemical-I', 'Mad_Transcendental_Fastest') 0.8006965642089419
# ('Chemical-I', 'Stl') 0.8181609286291015
# ('Chemical-I', 'Vdt') 0.81305413775354
# ('Concrete Compressive Strength', 'Eigen') 0.4462766739707051
# ('Concrete Compressive Strength', 'Mad_Transcendental_Fast') 0.46242470401402663
# ('Concrete Compressive Strength', 'Mad_Transcendental_Faster') 0.45237935506016114
# ('Concrete Compressive Strength', 'Mad_Transcendental_Fastest') 0.4673385461012412
# ('Concrete Compressive Strength', 'Stl') 0.44588559826263063
# ('Concrete Compressive Strength', 'Vdt') 0.4439940557373339
# ('Friedman-I', 'Eigen') 0.8650582917812253
# ('Friedman-I', 'Mad_Transcendental_Fast') 0.8650184910936766
# ('Friedman-I', 'Mad_Transcendental_Faster') 0.8650570235223272
# ('Friedman-I', 'Mad_Transcendental_Fastest') 0.8652730214103523
# ('Friedman-I', 'Stl') 0.8650063967718309
# ('Friedman-I', 'Vdt') 0.8650831848854819
# ('Friedman-II', 'Eigen') 0.9601239195770437
# ('Friedman-II', 'Mad_Transcendental_Fast') 0.9600393908964282
# ('Friedman-II', 'Mad_Transcendental_Faster') 0.9600376121269836
# ('Friedman-II', 'Mad_Transcendental_Fastest') 0.956996723266571
# ('Friedman-II', 'Stl') 0.9600200339650239
# ('Friedman-II', 'Vdt') 0.9599094529107205
# ('Poly-10', 'Eigen') 0.8743203747179229
# ('Poly-10', 'Mad_Transcendental_Fast') 0.8871735359439485
# ('Poly-10', 'Mad_Transcendental_Faster') 0.8862870089512802
# ('Poly-10', 'Mad_Transcendental_Fastest') 0.8073169158277728
# ('Poly-10', 'Stl') 0.8894740226766191
# ('Poly-10', 'Vdt') 0.8827157692601538
# ('Spatial Coevolution', 'Eigen') 0.9934410223487122
# ('Spatial Coevolution', 'Mad_Transcendental_Fast') 0.9948593760977972
# ('Spatial Coevolution', 'Mad_Transcendental_Faster') 0.9923075275607269
# ('Spatial Coevolution', 'Mad_Transcendental_Fastest') 0.9862121463367389
# ('Spatial Coevolution', 'Stl') 0.9931022859790788
# ('Spatial Coevolution', 'Vdt') 0.9927620087992788
# ('Vladislavleva-1', 'Eigen') 0.9974547491462118
# ('Vladislavleva-1', 'Mad_Transcendental_Fast') 0.9982481802761302
# ('Vladislavleva-1', 'Mad_Transcendental_Faster') 0.9983552057597813
# ('Vladislavleva-1', 'Mad_Transcendental_Fastest') 0.987719937970784
# ('Vladislavleva-1', 'Stl') 0.9981849386256667
# ('Vladislavleva-1', 'Vdt') 0.9976334062613144
# ('Vladislavleva-2', 'Eigen') 0.9989451866196039
# ('Vladislavleva-2', 'Mad_Transcendental_Fast') 0.9992498726418677
# ('Vladislavleva-2', 'Mad_Transcendental_Faster') 0.9991496563446023
# ('Vladislavleva-2', 'Mad_Transcendental_Fastest') 0.9963919536283385
# ('Vladislavleva-2', 'Stl') 0.9991549676411039
# ('Vladislavleva-2', 'Vdt') 0.9990520234597713
# ('Vladislavleva-3', 'Eigen') 0.9991461645177312
# ('Vladislavleva-3', 'Mad_Transcendental_Fast') 0.9991157376320053
# ('Vladislavleva-3', 'Mad_Transcendental_Faster') 0.9989494566683293
# ('Vladislavleva-3', 'Mad_Transcendental_Fastest') 0.9958722898930268
# ('Vladislavleva-3', 'Stl') 0.9991115045965324
# ('Vladislavleva-3', 'Vdt') 0.9990777162338413
# ('Vladislavleva-4', 'Eigen') 0.927753411532953
# ('Vladislavleva-4', 'Mad_Transcendental_Fast') 0.9637187675372629
# ('Vladislavleva-4', 'Mad_Transcendental_Faster') 0.9609761310637923
# ('Vladislavleva-4', 'Mad_Transcendental_Fastest') 0.8699515888124401
# ('Vladislavleva-4', 'Stl') 0.9487908458372819
# ('Vladislavleva-4', 'Vdt') 0.8962373750834778
# ('Vladislavleva-5', 'Eigen') 0.9999999456988573
# ('Vladislavleva-5', 'Mad_Transcendental_Fast') 0.9999999463581533
# ('Vladislavleva-5', 'Mad_Transcendental_Faster') 0.9999998959759773
# ('Vladislavleva-5', 'Mad_Transcendental_Fastest') 0.9998487783169632
# ('Vladislavleva-5', 'Stl') 0.9999999465922959
# ('Vladislavleva-5', 'Vdt') 0.9999998949292829
# ('Vladislavleva-6', 'Eigen') 0.9999999996735671
# ('Vladislavleva-6', 'Mad_Transcendental_Fast') 0.9999999999233745
# ('Vladislavleva-6', 'Mad_Transcendental_Faster') 0.999999999997589
# ('Vladislavleva-6', 'Mad_Transcendental_Fastest') 0.9927584356335676
# ('Vladislavleva-6', 'Stl') 0.9999999999330629
# ('Vladislavleva-6', 'Vdt') 0.9999999999045389
# ('Vladislavleva-7', 'Eigen') 0.9999999953047944
# ('Vladislavleva-7', 'Mad_Transcendental_Fast') 0.9999999949105056
# ('Vladislavleva-7', 'Mad_Transcendental_Faster') 0.9999999967534301
# ('Vladislavleva-7', 'Mad_Transcendental_Fastest') 0.9692883876666474
# ('Vladislavleva-7', 'Stl') 0.999999990387836
# ('Vladislavleva-7', 'Vdt') 0.9999999882071485
# ('Vladislavleva-8', 'Eigen') 0.8479664319108514
# ('Vladislavleva-8', 'Mad_Transcendental_Fast') 0.8594365790478959
# ('Vladislavleva-8', 'Mad_Transcendental_Faster') 0.8301108569695704
# ('Vladislavleva-8', 'Mad_Transcendental_Fastest') 0.8774680312027628
# ('Vladislavleva-8', 'Stl') 0.8666279393998314
# ('Vladislavleva-8', 'Vdt') 0.8543648021578759

# %%
df2
# Out:
#                  problem                        symbols  generation  r2_train  \
# 0     Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh       150.0     0.877
# 1     Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh       152.0     0.839
# 2     Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh       143.0     0.903
# 3     Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh       148.0     0.894
# 4     Airfoil Self-Noise  div_exp_log_sin_cos_sqrt_tanh       149.0     0.862
# ...                  ...                            ...         ...       ...
# 8995     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       139.0     0.999
# 8996     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       141.0     1.000
# 8997     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       141.0     1.000
# 8998     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       139.0     0.999
# 8999     Vladislavleva-8  div_exp_log_sin_cos_sqrt_tanh       142.0     1.000
#
#       r2_test  mae_train  mae_test  nmse_train  nmse_test  avg_fit  ...  \
# 0       0.592     1.8200     3.430    0.123000    0.40800   -0.752  ...
# 1       0.511     2.1200     3.730    0.161000    0.48900   -0.725  ...
# 2       0.573     1.5900     3.370    0.096700    0.42700   -0.776  ...
# 3       0.641     1.6800     3.180    0.106000    0.35900   -0.761  ...
# 4       0.488     1.9200     3.680    0.138000    0.51200   -0.742  ...
# ...       ...        ...       ...         ...        ...      ...  ...
# 8995    0.827     0.0250     0.409    0.001210    0.17300   -0.889  ...
# 8996    0.991     0.0133     0.116    0.000314    0.00909   -0.913  ...
# 8997    0.833     0.0168     0.380    0.000478    0.16700   -0.909  ...
# 8998    0.974     0.0182     0.166    0.000985    0.02630   -0.909  ...
# 8999    0.838     0.0145     0.402    0.000336    0.16200   -0.915  ...
#
#         opt_time          seed   elapsed  energy  \
# 0     75865786.0  1.943992e+09  2.978762  213.00
# 1     81079183.0  1.675822e+09  3.157546  221.00
# 2     90548652.0  3.711168e+07  3.421617  247.71
# 3     74271156.0  2.089412e+09  2.891453  209.22
# 4     79392822.0  3.227517e+09  3.102702  218.57
# ...          ...           ...       ...     ...
# 8995   6425966.0  3.646176e+08  0.383012   58.56
# 8996   7667115.0  3.388603e+09  0.427565   66.44
# 8997   6379898.0  3.318412e+09  0.379522   58.02
# 8998   7036831.0  3.237736e+09  0.405360   63.04
# 8999   7384731.0  1.630222e+09  0.423760   65.61
#
#                                              expression  \
# 0     ((-0.063319958746433258056641) + (1.0005155801...
# 1     ((-0.001388675533235073089600) + (1.0000110864...
# 2     ((-0.081726528704166412353516) + (1.0006757974...
# 3     ((-2.560159921646118164062500) + (1.0204287767...
# 4     ((-0.078155986964702606201172) + (1.0006164312...
# ...                                                 ...
# 8995  ((-0.000121150114864576607943) + (1.0000343322...
# 8996  (0.000002166297917938209139 + (1.0000050067901...
# 8997  ((-0.000867161026690155267715) + (1.0008423328...
# 8998  (0.000374341994756832718849 + (1.0012280941009...
# 8999  (0.002075307071208953857422 + (0.9990833997726...
#
#                         backend  r2_train_v  r2_test_v r2_train_b r2_test_b
# 0     Mad_Transcendental_Faster    0.876565   0.592853   0.876770  0.592257
# 1     Mad_Transcendental_Faster    0.839028   0.510691   0.839029  0.510691
# 2     Mad_Transcendental_Faster    0.903090   0.575136   0.903291  0.572915
# 3     Mad_Transcendental_Faster    0.893804   0.642033   0.893843  0.641491
# 4     Mad_Transcendental_Faster    0.863514   0.493437   0.862469  0.487620
# ...                         ...         ...        ...        ...       ...
# 8995                        Stl    0.998789   0.826594   0.998789  0.826594
# 8996                        Stl    0.999686   0.990913   0.999686  0.990913
# 8997                        Stl    0.999522   0.833338   0.999522  0.833338
# 8998                        Stl    0.999015   0.973672   0.999015  0.973672
# 8999                        Stl    0.999664   0.837645   0.999664  0.837645
#
# [9000 rows x 24 columns]
